# %% [markdown]
# # Affective Computing - Programming Assignment 0

# %% [markdown]
# **Objective**
# This exercise aims to give you an initial illustration on python programming.
#
# ## 0. Running Jupyter Notebook
#
# * Open the Virtual Machine
#     * Computers in room TS135 and TS137, you need use the virtual machine. "Start" -> "VMware Horizon Client" -> "Windows10"
#     * Computers in romm MA336, you will use the virtual machine by default after login on those machines.
#
# * Open "Anaconda Prompt"
#     * "Start" -> "Anaconda Prompt"
#
# * Run Jupyter Notebook
#     * using following command to run the Jupyter Notebook:
#     ```jupyter notebook --notebook-dir='yourNotebookDir'```, **yourNotebookDir** is the directory where you want ot implement your experiments.
#
#
# ## 0. Environment setting up and debuging
#
# ### 0.1. IDE
# You are also encouraged to using IDE during the development of your exercise, since the Jupyter Notebook may not friendly for debugging. So here we suggest two IDEs for you to debug your program:
# * Eclipse with pydev addons ([`pydev installation guide`](https://www.youtube.com/watch?v=4ZO0-AOSLwA))
# * PyCharm
#
# ### 0.2. Install packages
# During this course, you may need 3rd party packages which you may need to install by yourself, especially when you are using  your own computers. Below are some hints to install external packages:
# * ```pip install PACKAGE_NAME``` for python 2, ```pip3 install PACKAGE_NAME``` for python 3
# * If you do not have the root permission, you may use ```pip install PACKAGE_NAME --user``` to install package in your home folder.
# * If you want a package with specific version, you may use ```pip3 install PACKAGE_NAME==VERSION_CODE```
#
#
# ### 0.3. Import packages in your code
# * Import a package using ```import packageName```, then you can call function provided by the package by ```packageName.functionName()```
#   * EXAMPLE:
#       ```
#       import numpy
#       myEmptyArray = numpy.zeros([nRow, cCol], dtype=float)
#       ```
# * Import a package and give it another alias by ```import packageName as alias```, then you can use the alias to represent the package in your later code.
#   * EXAMPLE:
#       ```
#       import numpy as np
#       myEmptyArray = np.zeros([nRow, cCol], dtype=float)
#       ```
# * Directly import a function from a package by ```from packageName import functionName```, then you can directly call the function in your later code.
#   * EXAMPLE:
#       ```
#       from numpy import zeros
#       myEmptyArray = zeros([nRow, cCol], dtype=float)
#       ```
#
# ## 1. Input/Output
#
# ### 1.1. Read .mat data
# In this course, data are provided by **.mat** files. You may use [`scipy.io.load()`] function to load **.mat** files. You can also use [`h5py`](https://www.h5py.org/).
#
#
# **YOU ARE NOT RECOMMEDED TO USE SUCH LONG FUNCTION NAME SUCH AS ```scipy.io.loadmat()```. A better way to do this is**
#
# ```
# import scipy.io as sio
# sio.loadmat()
# ```
#
# Moreover Each file may contain several data objects. If we load it in python, these data objects will be regarded as dictories, and each data object can be accessed using corresponding dictionary name.
# * Example: we have a data file *myDataFile.mat* which contains following data object (or dictionaries): *dic1*, *dic2*, ... Then
# ```
# import scipy.sio as sio
# myDic1Data = sio.loadmat('myDataFile.mat')['dic1']
# ```
#
#
#
# ### 1.2. Read.csv
# You can use **csv** package to interact with *.csv* files. **csv** package is a standard package of python, you do not need install it by yourself. A basic structure for reading a csv file is described as follows:
# ```
# with open('myCsv.csv', 'rb') as csvfile:
#     spamreader = csv.reader(csvfile, delimiter=',')
#     for row in spamreader:
#         # Remeber, python indices start from 0
#         print(row[0])
#         print(row[1])
#         ...
#         ```
#
#
# ### 1.3. Read image
# You can use the [`scikit-image`](https://scikit-image.org/) for image processing. To read an image, you can used [`skimage.io.imread()`](http://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread):
#
# ```
# from skimage.io import imread
# mPxl = imread('mImage.jpg')
# ```
#
#
#
# ### 1.4. Plotting
# [`matplot.pyplot`](https://matplotlib.org/api/pyplot_api.html) is a very effective plotting tool. It support single plot, and subplots. Code block below is an example to make subplots:
# ```
#
# import matplotlib.pyplot as plt
# fig,ax = plt.subplots(1,2, figsize=(15, 8))
# ax[0].imshow(some picture)
# ax[1].imshow(some picture)
# #fig.tight_layout()
# plt.show()
#
# ```
#
# ## 2. Numerical Computation
# [`numpy`](http://www.numpy.org/) is the main tool for array processing. Here we provide some example usages of several functions:
# * numpy.zeros([a, b, c]): create a zero array with the dimension of *a x b x c*
# * numpy.ones([a, b, c]): create an one array with the dimension of *a x b x c*
# * numpy.linspace(start, end, num): craete an array of *num* elements which are equally distributed in the interval between *start* and *end*
# * numpy.std(axis)/numpy.mean(axis): calculate the mean/std along a specific axis.
